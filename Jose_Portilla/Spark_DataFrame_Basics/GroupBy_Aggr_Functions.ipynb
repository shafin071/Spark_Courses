# %%
from pyspark.sql import SparkSession
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
spark = SparkSession.builder.appName('aggs').getOrCreate()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
df = spark.read.csv('/FileStore/tables/sales_info.csv', inferSchema=True, header=True)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
df.show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+-------+-------+-----+
# Company| Person|Sales|
# +-------+-------+-----+
#    GOOG|    Sam|200.0|
#    GOOG|Charlie|120.0|
#    GOOG|  Frank|340.0|
#    MSFT|   Tina|600.0|
#    MSFT|    Amy|124.0|
#    MSFT|Vanessa|243.0|
#      FB|   Carl|870.0|
#      FB|  Sarah|350.0|
#    APPL|   John|250.0|
#    APPL|  Linda|130.0|
#    APPL|   Mike|750.0|
#    APPL|  Chris|350.0|
# +-------+-------+-----+
#
# </div>

# %%
df.printSchema()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">root
# -- Company: string (nullable = true)
# -- Person: string (nullable = true)
# -- Sales: double (nullable = true)
#
# </div>

# %%
df.groupBy('Company').mean().show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+-------+-----------------+
# Company|       avg(Sales)|
# +-------+-----------------+
#    APPL|            370.0|
#    GOOG|            220.0|
#      FB|            610.0|
#    MSFT|322.3333333333333|
# +-------+-----------------+
#
# </div>

# %%
df.groupBy('Company').count().show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+-------+-----+
# Company|count|
# +-------+-----+
#    APPL|    4|
#    GOOG|    3|
#      FB|    2|
#    MSFT|    3|
# +-------+-----+
#
# </div>

# %%
df.agg({'Sales': 'sum'}).show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+----------+
# sum(Sales)|
# +----------+
#     4327.0|
# +----------+
#
# </div>

# %%
group_data = df.groupby('Company')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
group_data.agg({'Sales': 'max'}).show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+-------+----------+
# Company|max(Sales)|
# +-------+----------+
#    APPL|     750.0|
#    GOOG|     340.0|
#      FB|     870.0|
#    MSFT|     600.0|
# +-------+----------+
#
# </div>

# %%
from pyspark.sql.functions import countDistinct, avg, stddev
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
df.select(countDistinct('Sales')).show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+---------------------+
# count(DISTINCT Sales)|
# +---------------------+
#                    11|
# +---------------------+
#
# </div>

# %%
df.select(countDistinct('Company')).show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+-----------------------+
# count(DISTINCT Company)|
# +-----------------------+
#                       4|
# +-----------------------+
#
# </div>

# %%
spark.sql('SELECT COUNT(DISTINCT Company) FROM sales_info_csv').show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+-----------------------+
# count(DISTINCT Company)|
# +-----------------------+
#                       4|
# +-----------------------+
#
# </div>

# %%
df.select(avg('Sales').alias('Avg Sales')).show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+-----------------+
#         Avg Sales|
# +-----------------+
# 360.5833333333333|
# +-----------------+
#
# </div>

# %%
df.select(stddev('Sales')).show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+------------------+
# stddev_samp(Sales)|
# +------------------+
# 250.08742410799007|
# +------------------+
#
# </div>

# %%
from pyspark.sql.functions import format_number
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
sales_std = df.select(stddev('Sales').alias('Sales_std')).select(format_number('Sales_std', 2).alias('Sales_std')).show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+---------+
# Sales_std|
# +---------+
#    250.09|
# +---------+
#
# </div>

# %%
df.show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+-------+-------+-----+
# Company| Person|Sales|
# +-------+-------+-----+
#    GOOG|    Sam|200.0|
#    GOOG|Charlie|120.0|
#    GOOG|  Frank|340.0|
#    MSFT|   Tina|600.0|
#    MSFT|    Amy|124.0|
#    MSFT|Vanessa|243.0|
#      FB|   Carl|870.0|
#      FB|  Sarah|350.0|
#    APPL|   John|250.0|
#    APPL|  Linda|130.0|
#    APPL|   Mike|750.0|
#    APPL|  Chris|350.0|
# +-------+-------+-----+
#
# </div>

# %%
df.orderBy("Sales").show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+-------+-------+-----+
# Company| Person|Sales|
# +-------+-------+-----+
#    GOOG|Charlie|120.0|
#    MSFT|    Amy|124.0|
#    APPL|  Linda|130.0|
#    GOOG|    Sam|200.0|
#    MSFT|Vanessa|243.0|
#    APPL|   John|250.0|
#    GOOG|  Frank|340.0|
#      FB|  Sarah|350.0|
#    APPL|  Chris|350.0|
#    MSFT|   Tina|600.0|
#    APPL|   Mike|750.0|
#      FB|   Carl|870.0|
# +-------+-------+-----+
#
# </div>

# %%
df.orderBy(df['Sales'].desc()).show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+-------+-------+-----+
# Company| Person|Sales|
# +-------+-------+-----+
#      FB|   Carl|870.0|
#    APPL|   Mike|750.0|
#    MSFT|   Tina|600.0|
#      FB|  Sarah|350.0|
#    APPL|  Chris|350.0|
#    GOOG|  Frank|340.0|
#    APPL|   John|250.0|
#    MSFT|Vanessa|243.0|
#    GOOG|    Sam|200.0|
#    APPL|  Linda|130.0|
#    MSFT|    Amy|124.0|
#    GOOG|Charlie|120.0|
# +-------+-------+-----+
#
# </div>
